# %%
import pandas as pd

# %%
CSV_PATH = "features.csv"

# %%
features_df = pd.read_csv(CSV_PATH)

# %%
print(features_df.head())
# Out:
#             0           1          2          3          4          5  \
# 0 -119.018044  125.080353 -23.394335  41.321732  -5.931896  20.092751
# 1 -125.977150  122.374191 -20.679750  50.035042 -11.250690  21.386393
# 2 -132.618149  114.815521 -14.718568  50.017944  -0.424878  24.517357
# 3 -118.325325  131.587173 -18.493637  39.478863 -12.992121  20.173027
# 4 -106.182106  134.275955 -19.761967  39.920498 -14.074066  18.501814
#
#            6          7          8          9  ...        19        20  \
# 0 -16.031523  17.811024 -14.643774  10.218312  ...  0.271127  0.300573
# 1 -15.864703  19.418631 -12.440535  17.862537  ...  0.483460  0.499978
# 2 -13.401937  15.444255 -13.006782  10.309508  ...  0.227462  0.379300
# 3 -14.325366  18.541624 -13.470632  12.837085  ...  0.362261  0.389526
# 4 -15.400158  19.148363 -17.971155  14.170511  ...  0.327873  0.443653
#
#          21        22        23        24           25           26        27  \
# ...
